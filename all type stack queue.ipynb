# %%
#Problem: Implement a stack and perform basic operations such as push, pop, and peek

class Stack:
    def __init__(self):
        self.stack = []

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        if not self.is_empty():
            return self.stack.pop()
        else:
            print("Stack is empty.")

    def peek(self):
        if not self.is_empty():
            return self.stack[-1]
        else:
            print("Stack is empty.")

    def is_empty(self):
        return len(self.stack) == 0
    
    def print_Stack(self):
        if not self.is_empty():
            for abc in self.data:
                print(abc)

        else:
            print("This Stack is empty")

stack = Stack()
stack.push(5)
stack.push(10)
stack.push(15)
Stack.print_Stack()
print(stack.peek())  
stack.pop()
print(stack.peek())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 37
#      35 stack.push(10)
#      36 stack.push(15)
# ---> 37 Stack.print_Stack()
#      38 print(stack.peek())
#      39 stack.pop()
#
# TypeError: Stack.print_Stack() missing 1 required positional argument: 'self'

# %%
#Problem: Implement a queue and perform basic operations such as enqueue, dequeue, and peek.

class Queue:
    def __init__(self):
        self.queue = []

    def enqueue(self, item):
        self.queue.append(item)

    def dequeue(self):
        if not self.is_empty():
            return self.queue.pop(0)
        else:
            print("Queue is empty.")

    def peek(self):
        if not self.is_empty():
            return self.queue[0]
        else:
            print("Queue is empty.")

    def is_empty(self):
        return len(self.queue) == 0

queue = Queue()
queue.enqueue(50)
queue.enqueue(100)
queue.enqueue(15)
queue.enqueue(20)

print(queue.peek())  # Output: 5
queue.dequeue()
print(queue.peek())  # Output: 10
# Out:
# 50
# 100

# %%
#Problem: Check if a given string is a palindrome using a stack.

class Stack:
    def __init__(self):
        self.stack = []

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        if not self.is_empty():
            return self.stack.pop()
        else:
            print("Stack is empty.")

    def peek(self):
        if not self.is_empty():
            return self.stack[-1]
        else:
            print("Stack is empty.")

    def is_empty(self):
        return len(self.stack) == 0

def is_palindrome(word):
    stack = Stack()
    for char in word:
        stack.push(char)
    
    reversed_word = ""
    while not stack.is_empty():
        reversed_word += stack.pop()
    
    return word == reversed_word

word = "shanto"
print(is_palindrome(word))  # Output: True
# Out:
# False

# %%
#Problem: Check if parentheses in a given expression are balanced using a stack.

class Stack:
    def __init__(self):
        self.stack = []

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        if not self.is_empty():
            return self.stack.pop()
        else:
            print("Stack is empty.")

    def peek(self):
        if not self.is_empty():
            return self.stack[-1]
        else:
            print("Stack is empty.")

    def is_empty(self):
        return len(self.stack) == 0

def are_parentheses_balanced(expression):
    stack = Stack()
    opening_brackets = ["(", "[", "{"]
    closing_brackets = [")", "]", "}"]
    for char in expression:
        if char in opening_brackets:
            stack.push(char)
        elif char in closing_brackets:
            if stack.is_empty():
                return False
            top = stack.pop()
            if opening_brackets.index(top) != closing_brackets.index(char):
                return False

    return stack.is_empty()

expression = "{[)]}"
print(are_parentheses_balanced(expression))  # Output: True
# Out:
# False

# %%
#Problem: Implement a queue using two stacks.

class Queue:
    def __init__(self):
        self.stack1 = []
        self.stack2 = []

    def enqueue(self, item):
        self.stack1.append(item)

    def dequeue(self):
        if self.is_empty():
            print("Queue is empty.")
            return None

        if not self.stack2:
            while self.stack1:
                self.stack2.append(self.stack1.pop())

        return self.stack2.pop()

    def peek(self):
        if self.is_empty():
            print("Queue is empty.")
            return None

        if not self.stack2:
            while self.stack1:
                self.stack2.append(self.stack1.pop())

        return self.stack2[-1]

    def is_empty(self):
        return len(self.stack1) + len(self.stack2) == 0

queue = Queue()
queue.enqueue(5)
queue.enqueue(10)
queue.enqueue(15)
print(queue.peek())  # Output: 5
queue.dequeue()
print(queue.peek())  # Output: 10
# Out:
# 5
# 10

# %%
#Problem: Reverse a queue using a stack.

class Stack:
    def __init__(self):
        self.stack = []

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        if not self.is_empty():
            return self.stack.pop()
        else:
            print("Stack is empty.")

    def peek(self):
        if not self.is_empty():
            return self.stack[-1]
        else:
            print("Stack is empty.")

    def is_empty(self):
        return len(self.stack) == 0


class Queue:
    def __init__(self):
        self.queue = []

    def enqueue(self, item):
        self.queue.append(item)

    def dequeue(self):
        if not self.is_empty():
            return self.queue.pop(0)
        else:
            print("Queue is empty.")

    def peek(self):
        if not self.is_empty():
            return self.queue[0]
        else:
            print("Queue is empty.")

    def is_empty(self):
        return len(self.queue) == 0

    def reverse(self):
        stack = Stack()
        while not self.is_empty():
            stack.push(self.dequeue())
        
        while not stack.is_empty():
            self.enqueue(stack.pop())

queue = Queue()
queue.enqueue(5)
queue.enqueue(10)
queue.enqueue(15)
queue.reverse()
print(queue.dequeue())  # Output: 15
print(queue.dequeue())  # Output: 10
print(queue.dequeue())  # Output: 5
# Out:
# 15
# 10
# 5

# %%
# Problem: Check if a given string is a palindrome using a queue.

class Queue:
    def __init__(self):
        self.queue = []

    def enqueue(self, item):
        self.queue.append(item)

    def dequeue(self):
        if not self.is_empty():
            return self.queue.pop(0)
        else:
            print("Queue is empty.")

    def peek(self):
        if not self.is_empty():
            return self.queue[0]
        else:
            print("Queue is empty.")

    def is_empty(self):
        return len(self.queue) == 0

def is_palindrome(word):
    queue = Queue()
    for char in word:
        queue.enqueue(char)
    
    reversed_word = ""
    while not queue.is_empty():
        reversed_word += queue.dequeue()
    
    return word == reversed_word

word = "shanto"
print(is_palindrome(word))  # Output: True
# Out:
# True

# %%
class Stack:
    def __init__(self):
        self.stack = []

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        if not self.is_empty():
            return self.stack.pop()
        else:
            return None

    def is_empty(self):
        return len(self.stack) == 0

    def size(self):
        return len(self.stack)

    def peek(self):
        if not self.is_empty():
            return self.stack[-1]
        else:
            return None


# Example usage:
stack = Stack()
stack.push(1)
stack.push(2)
stack.push(3)
stack.push(4)
stack.push(5)

print("Stack size:", stack.size())
print("Stack elements:")
while not stack.is_empty():
    print(stack.pop())
# Out:
# Stack size: 5
# Stack elements:
# 5
# 4
# 3
# 2
# 1
